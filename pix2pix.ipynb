# %%
# %%writefile config.py
import torch
import albumentations as A
from albumentations.pytorch import ToTensorV2

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# WARNING: Update these paths to match where your dataset is located in /kaggle/input/
TRAIN_DIR = "/kaggle/input/pix2pix-dataset/maps/maps/train"
VAL_DIR = "/kaggle/input/pix2pix-dataset/maps/maps/val"

LEARNING_RATE = 2e-4
BATCH_SIZE = 16
NUM_WORKERS = 2
IMAGE_SIZE = 256
CHANNELS_IMG = 3
L1_LAMBDA = 100
LAMBDA_GP = 10
NUM_EPOCHS = 500
LOAD_MODEL = False
SAVE_MODEL = True
CHECKPOINT_DISC = "disc.pth.tar"
CHECKPOINT_GEN = "gen.pth.tar"

both_transform = A.Compose(
    [
        A.Resize(width=256, height=256),
        A.HorizontalFlip(p=0.5),
    ], 
    additional_targets={"image0": "image"},
)

transform_only_input = A.Compose(
    [
        A.ColorJitter(p=0.2),
        A.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5], max_pixel_value=255.0,),
        ToTensorV2(),
    ]
)

transform_only_mask = A.Compose(
    [
        A.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5], max_pixel_value=255.0,),
        ToTensorV2(),
    ]
)
# Out:
# Writing config.py

# %%
# %%writefile dataset.py
import numpy as np
import config
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import save_image


class MapDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = root_dir
        self.list_files = os.listdir(self.root_dir)

    def __len__(self):
        return len(self.list_files)

    def __getitem__(self, index):
        img_file = self.list_files[index]
        img_path = os.path.join(self.root_dir, img_file)
        image = np.array(Image.open(img_path))
        input_image = image[:, :600, :]
        target_image = image[:, 600:, :]

        augmentations = config.both_transform(image=input_image, image0=target_image)
        input_image = augmentations["image"]
        target_image = augmentations["image0"]

        input_image = config.transform_only_input(image=input_image)["image"]
        target_image = config.transform_only_mask(image=target_image)["image"]

        return input_image, target_image


if __name__ == "__main__":
    dataset = MapDataset("data/train/")
    loader = DataLoader(dataset, batch_size=5)
    for x, y in loader:
        print(x.shape)
        save_image(x, "x.png")
        save_image(y, "y.png")
        import sys

        sys.exit()
# Out:
# Writing dataset.py

# %%
# %%writefile generator_model.py

import torch
import torch.nn as nn


class Block(nn.Module):
    def __init__(self, in_channels, out_channels, down=True, act="relu", use_dropout=False):
        super(Block, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 4, 2, 1, bias=False, padding_mode="reflect")
            if down
            else nn.ConvTranspose2d(in_channels, out_channels, 4, 2, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU() if act == "relu" else nn.LeakyReLU(0.2),
        )

        self.use_dropout = use_dropout
        self.dropout = nn.Dropout(0.5)
        self.down = down

    def forward(self, x):
        x = self.conv(x)
        return self.dropout(x) if self.use_dropout else x


class Generator(nn.Module):
    def __init__(self, in_channels=3, features=64):
        super().__init__()
        self.initial_down = nn.Sequential(
            nn.Conv2d(in_channels, features, 4, 2, 1, padding_mode="reflect"),
            nn.LeakyReLU(0.2),
        )
        self.down1 = Block(features, features * 2, down=True, act="leaky", use_dropout=False)
        self.down2 = Block(
            features * 2, features * 4, down=True, act="leaky", use_dropout=False
        )
        self.down3 = Block(
            features * 4, features * 8, down=True, act="leaky", use_dropout=False
        )
        self.down4 = Block(
            features * 8, features * 8, down=True, act="leaky", use_dropout=False
        )
        self.down5 = Block(
            features * 8, features * 8, down=True, act="leaky", use_dropout=False
        )
        self.down6 = Block(
            features * 8, features * 8, down=True, act="leaky", use_dropout=False
        )
        self.bottleneck = nn.Sequential(
            nn.Conv2d(features * 8, features * 8, 4, 2, 1), nn.ReLU()
        )

        self.up1 = Block(features * 8, features * 8, down=False, act="relu", use_dropout=True)
        self.up2 = Block(
            features * 8 * 2, features * 8, down=False, act="relu", use_dropout=True
        )
        self.up3 = Block(
            features * 8 * 2, features * 8, down=False, act="relu", use_dropout=True
        )
        self.up4 = Block(
            features * 8 * 2, features * 8, down=False, act="relu", use_dropout=False
        )
        self.up5 = Block(
            features * 8 * 2, features * 4, down=False, act="relu", use_dropout=False
        )
        self.up6 = Block(
            features * 4 * 2, features * 2, down=False, act="relu", use_dropout=False
        )
        self.up7 = Block(features * 2 * 2, features, down=False, act="relu", use_dropout=False)
        self.final_up = nn.Sequential(
            nn.ConvTranspose2d(features * 2, in_channels, kernel_size=4, stride=2, padding=1),
            nn.Tanh(),
        )

    def forward(self, x):
        d1 = self.initial_down(x)
        d2 = self.down1(d1)
        d3 = self.down2(d2)
        d4 = self.down3(d3)
        d5 = self.down4(d4)
        d6 = self.down5(d5)
        d7 = self.down6(d6)
        bottleneck = self.bottleneck(d7)
        up1 = self.up1(bottleneck)
        up2 = self.up2(torch.cat([up1, d7], 1))
        up3 = self.up3(torch.cat([up2, d6], 1))
        up4 = self.up4(torch.cat([up3, d5], 1))
        up5 = self.up5(torch.cat([up4, d4], 1))
        up6 = self.up6(torch.cat([up5, d3], 1))
        up7 = self.up7(torch.cat([up6, d2], 1))
        return self.final_up(torch.cat([up7, d1], 1))


def test():
    x = torch.randn((1, 3, 256, 256))
    model = Generator(in_channels=3, features=64)
    preds = model(x)
    print(preds.shape)


if __name__ == "__main__":
    test()
# Out:
# Writing generator_model.py

# %%
# %%writefile discriminator_model.py

import torch
import torch.nn as nn


class CNNBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride):
        super(CNNBlock, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(
                in_channels, out_channels, 4, stride, 1, bias=False, padding_mode="reflect"
            ),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.conv(x)


class Discriminator(nn.Module):
    def __init__(self, in_channels=3, features=[64, 128, 256, 512]):
        super().__init__()
        self.initial = nn.Sequential(
            nn.Conv2d(
                in_channels * 2,
                features[0],
                kernel_size=4,
                stride=2,
                padding=1,
                padding_mode="reflect",
            ),
            nn.LeakyReLU(0.2),
        )

        layers = []
        in_channels = features[0]
        for feature in features[1:]:
            layers.append(
                CNNBlock(in_channels, feature, stride=1 if feature == features[-1] else 2),
            )
            in_channels = feature

        layers.append(
            nn.Conv2d(
                in_channels, 1, kernel_size=4, stride=1, padding=1, padding_mode="reflect"
            ),
        )

        self.model = nn.Sequential(*layers)

    def forward(self, x, y):
        x = torch.cat([x, y], dim=1)
        x = self.initial(x)
        x = self.model(x)
        return x


def test():
    x = torch.randn((1, 3, 256, 256))
    y = torch.randn((1, 3, 256, 256))
    model = Discriminator(in_channels=3)
    preds = model(x, y)
    print(model)
    print(preds.shape)


if __name__ == "__main__":
    test()
# Out:
# Writing discriminator_model.py

# %%
# %%writefile utils.py

import torch
import config
from torchvision.utils import save_image

def save_some_examples(gen, val_loader, epoch, folder):
    x, y = next(iter(val_loader))
    x, y = x.to(config.DEVICE), y.to(config.DEVICE)
    gen.eval()
    with torch.no_grad():
        y_fake = gen(x)
        y_fake = y_fake * 0.5 + 0.5  # remove normalization#
        save_image(y_fake, folder + f"/y_gen_{epoch}.png")
        save_image(x * 0.5 + 0.5, folder + f"/input_{epoch}.png")
        if epoch == 1:
            save_image(y * 0.5 + 0.5, folder + f"/label_{epoch}.png")
    gen.train()


def save_checkpoint(model, optimizer, filename="my_checkpoint.pth.tar"):
    print("=> Saving checkpoint")
    checkpoint = {
        "state_dict": model.state_dict(),
        "optimizer": optimizer.state_dict(),
    }
    torch.save(checkpoint, filename)


def load_checkpoint(checkpoint_file, model, optimizer, lr):
    print("=> Loading checkpoint")
    checkpoint = torch.load(checkpoint_file, map_location=config.DEVICE)
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])

    # If we don't do this then it will just have learning rate of old checkpoint
    # and it will lead to many hours of debugging \:
    for param_group in optimizer.param_groups:
        param_group["lr"] = lr
# Out:
# Writing utils.py

# %%
# %%writefile train.py

import torch
from utils import save_checkpoint, load_checkpoint, save_some_examples
import torch.nn as nn
import torch.optim as optim
import config
from dataset import MapDataset
from generator_model import Generator
from discriminator_model import Discriminator
from torch.utils.data import DataLoader
from tqdm import tqdm
from torchvision.utils import save_image

torch.backends.cudnn.benchmark = True


def train_fn(
    disc, gen, loader, opt_disc, opt_gen, l1_loss, bce, g_scaler, d_scaler,
):
    loop = tqdm(loader, leave=True)

    for idx, (x, y) in enumerate(loop):
        x = x.to(config.DEVICE)
        y = y.to(config.DEVICE)

        # Train Discriminator
        with torch.cuda.amp.autocast():
            y_fake = gen(x)
            D_real = disc(x, y)
            D_real_loss = bce(D_real, torch.ones_like(D_real))
            D_fake = disc(x, y_fake.detach())
            D_fake_loss = bce(D_fake, torch.zeros_like(D_fake))
            D_loss = (D_real_loss + D_fake_loss) / 2

        disc.zero_grad()
        d_scaler.scale(D_loss).backward()
        d_scaler.step(opt_disc)
        d_scaler.update()

        # Train generator
        with torch.cuda.amp.autocast():
            D_fake = disc(x, y_fake)
            G_fake_loss = bce(D_fake, torch.ones_like(D_fake))
            L1 = l1_loss(y_fake, y) * config.L1_LAMBDA
            G_loss = G_fake_loss + L1

        opt_gen.zero_grad()
        g_scaler.scale(G_loss).backward()
        g_scaler.step(opt_gen)
        g_scaler.update()

        if idx % 10 == 0:
            loop.set_postfix(
                D_real=torch.sigmoid(D_real).mean().item(),
                D_fake=torch.sigmoid(D_fake).mean().item(),
            )


def main():
    disc = Discriminator(in_channels=3).to(config.DEVICE)
    gen = Generator(in_channels=3, features=64).to(config.DEVICE)
    opt_disc = optim.Adam(disc.parameters(), lr=config.LEARNING_RATE, betas=(0.5, 0.999),)
    opt_gen = optim.Adam(gen.parameters(), lr=config.LEARNING_RATE, betas=(0.5, 0.999))
    BCE = nn.BCEWithLogitsLoss()
    L1_LOSS = nn.L1Loss()

    if config.LOAD_MODEL:
        load_checkpoint(
            config.CHECKPOINT_GEN, gen, opt_gen, config.LEARNING_RATE,
        )
        load_checkpoint(
            config.CHECKPOINT_DISC, disc, opt_disc, config.LEARNING_RATE,
        )

    train_dataset = MapDataset(root_dir=config.TRAIN_DIR)
    train_loader = DataLoader(
        train_dataset,
        batch_size=config.BATCH_SIZE,
        shuffle=True,
        num_workers=config.NUM_WORKERS,
    )
    g_scaler = torch.cuda.amp.GradScaler()
    d_scaler = torch.cuda.amp.GradScaler()
    val_dataset = MapDataset(root_dir=config.VAL_DIR)
    val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)

    for epoch in range(config.NUM_EPOCHS):
        train_fn(
            disc, gen, train_loader, opt_disc, opt_gen, L1_LOSS, BCE, g_scaler, d_scaler,
        )

        if config.SAVE_MODEL and epoch % 5 == 0:
            save_checkpoint(gen, opt_gen, filename=config.CHECKPOINT_GEN)
            save_checkpoint(disc, opt_disc, filename=config.CHECKPOINT_DISC)

        save_some_examples(gen, val_loader, epoch, folder="evaluation")


if __name__ == "__main__":
    main()
# Out:
# Writing train.py

# %%
import os
os.makedirs("evaluation", exist_ok=True)

# %%
# !python train.py
# Out:
# /kaggle/working/train.py:82: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   g_scaler = torch.cuda.amp.GradScaler()
# /kaggle/working/train.py:83: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   d_scaler = torch.cuda.amp.GradScaler()
#   0%|                                                    | 0/69 [00:00<?, ?it/s]/kaggle/working/train.py:27: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /kaggle/working/train.py:41: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# 100%|██████████████| 69/69 [00:50<00:00,  1.36it/s, D_fake=0.0983, D_real=0.802]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.171, D_real=0.923]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.505, D_real=0.429]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.532, D_real=0.134]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.327, D_real=0.513]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.625, D_real=0.289]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.082, D_real=0.752]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.112, D_real=0.767]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.182, D_real=0.688]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.132, D_real=0.777]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.18, D_real=0.845]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.461, D_real=0.595]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.724, D_real=0.401]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.147, D_real=0.714]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.356, D_real=0.76]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.478, D_real=0.422]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.118, D_real=0.812]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.26, D_real=0.787]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.461, D_real=0.618]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.101, D_real=0.93]
# 100%|█████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.1, D_real=0.706]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.347, D_real=0.631]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.385, D_real=0.351]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.22, D_real=0.674]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.144, D_real=0.779]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.205, D_real=0.937]
# => Saving checkpoint
# => Saving checkpoint
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.287, D_real=0.53]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.42, D_real=0.444]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.448, D_real=0.703]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.215, D_real=0.607]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.261, D_real=0.683]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.227, D_real=0.674]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.318, D_real=0.576]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.165, D_real=0.848]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.479, D_real=0.391]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.339, D_real=0.447]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.172, D_real=0.888]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.521, D_real=0.52]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.286, D_real=0.671]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.297, D_real=0.657]
# 100%|█████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.372, D_real=0.4]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.285, D_real=0.637]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.174, D_real=0.792]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.249, D_real=0.481]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.275, D_real=0.818]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.211, D_real=0.755]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.161, D_real=0.846]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.518, D_real=0.501]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.402, D_real=0.181]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.162, D_real=0.774]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.263, D_real=0.758]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.404, D_real=0.659]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.471, D_real=0.729]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.575, D_real=0.418]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.255, D_real=0.595]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.371, D_real=0.649]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.409, D_real=0.741]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.395, D_real=0.319]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.301, D_real=0.408]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.249, D_real=0.759]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.136, D_real=0.873]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.037, D_real=0.763]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.039, D_real=0.942]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.152, D_real=0.722]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0818, D_real=0.908]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0334, D_real=0.917]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0506, D_real=0.938]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00463, D_real=0.61]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.101, D_real=0.917]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0449, D_real=0.928]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0591, D_real=0.969]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.134, D_real=0.919]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0101, D_real=0.939]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.003, D_real=0.983]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0656, D_real=0.851]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00144, D_real=0.985]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.121, D_real=0.746]
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.121, D_real=0.95]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0208, D_real=0.976]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.191, D_real=0.469]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0627, D_real=0.982]
# => Saving checkpoint
# => Saving checkpoint
# 100%|████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.000591, D_real=0.985]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0691, D_real=0.978]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0253, D_real=0.275]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0269, D_real=0.928]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0129, D_real=0.991]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0113, D_real=0.653]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0471, D_real=0.997]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00162, D_real=0.983]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00186, D_real=0.943]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00854, D_real=0.393]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00132, D_real=0.945]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00657, D_real=0.994]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.217, D_real=0.476]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0298, D_real=0.981]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00988, D_real=0.981]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0359, D_real=0.939]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0307, D_real=0.783]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0231, D_real=0.968]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0438, D_real=0.954]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0283, D_real=0.985]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0264, D_real=0.998]
# 100%|██████████████| 69/69 [00:21<00:00,  3.22it/s, D_fake=0.0407, D_real=0.992]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0127, D_real=0.943]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.307, D_real=0.66]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0596, D_real=0.781]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0164, D_real=0.91]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.014, D_real=0.916]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0821, D_real=0.962]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0294, D_real=0.966]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0255, D_real=0.898]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0218, D_real=0.973]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.107, D_real=0.788]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0444, D_real=0.962]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0118, D_real=0.968]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0817, D_real=0.899]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0361, D_real=0.967]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0938, D_real=0.598]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0602, D_real=0.949]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0674, D_real=0.968]
# 100%|█████████████| 69/69 [00:21<00:00,  3.22it/s, D_fake=0.00111, D_real=0.993]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00601, D_real=0.952]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.02, D_real=0.816]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0653, D_real=0.896]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.079, D_real=0.731]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0197, D_real=0.987]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0282, D_real=0.889]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.112, D_real=0.817]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0567, D_real=0.924]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.03, D_real=0.976]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0327, D_real=0.927]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.111, D_real=0.651]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.171, D_real=0.411]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0574, D_real=0.961]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00413, D_real=0.951]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0334, D_real=0.897]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00395, D_real=0.896]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00718, D_real=0.958]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.149, D_real=0.91]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.211, D_real=0.836]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0398, D_real=0.978]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0139, D_real=0.995]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0497, D_real=0.979]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0437, D_real=0.77]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0711, D_real=0.929]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.041, D_real=0.887]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.392, D_real=0.424]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0113, D_real=0.995]
# 100%|██████████████| 69/69 [00:21<00:00,  3.19it/s, D_fake=0.0246, D_real=0.857]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0101, D_real=0.974]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0082, D_real=0.992]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0684, D_real=0.987]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0336, D_real=0.899]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0128, D_real=0.954]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.148, D_real=0.833]
# 100%|██████████████| 69/69 [00:21<00:00,  3.22it/s, D_fake=0.0256, D_real=0.924]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0259, D_real=0.95]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0238, D_real=0.981]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00609, D_real=0.949]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0265, D_real=0.957]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00258, D_real=0.972]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00668, D_real=0.985]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0467, D_real=0.951]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0122, D_real=0.557]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.161, D_real=0.724]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0788, D_real=0.95]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.104, D_real=0.682]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0482, D_real=0.94]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0738, D_real=0.896]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.062, D_real=0.735]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.233, D_real=0.771]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.102, D_real=0.855]
# 100%|██████████████| 69/69 [00:21<00:00,  3.22it/s, D_fake=0.0189, D_real=0.954]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.014, D_real=0.877]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0393, D_real=0.936]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.194, D_real=0.835]
# => Saving checkpoint
# => Saving checkpoint
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.061, D_real=0.94]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0045, D_real=0.913]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00291, D_real=0.957]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0181, D_real=0.973]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0432, D_real=0.949]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00192, D_real=0.949]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0662, D_real=0.988]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00164, D_real=0.989]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0464, D_real=0.818]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.014, D_real=0.983]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.116, D_real=0.9]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0836, D_real=0.955]
# 100%|██████████████| 69/69 [00:21<00:00,  3.22it/s, D_fake=0.0145, D_real=0.969]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00747, D_real=0.992]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.026, D_real=0.99]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0397, D_real=0.949]
# 100%|█████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00992, D_real=0.443]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0273, D_real=0.981]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0629, D_real=0.951]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0773, D_real=0.867]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0375, D_real=0.76]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.188, D_real=0.926]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0525, D_real=0.992]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.081, D_real=0.843]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00388, D_real=0.868]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0168, D_real=0.97]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0936, D_real=0.868]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0385, D_real=0.904]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0106, D_real=0.845]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0547, D_real=0.781]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.189, D_real=0.856]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.025, D_real=0.729]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00789, D_real=0.934]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0444, D_real=0.759]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0383, D_real=0.938]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.134, D_real=0.827]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0977, D_real=0.9]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0217, D_real=0.973]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00732, D_real=0.914]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0336, D_real=0.923]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0202, D_real=0.995]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0459, D_real=0.579]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0196, D_real=0.955]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0116, D_real=0.968]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0213, D_real=0.965]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0578, D_real=0.971]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00558, D_real=0.959]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00558, D_real=0.973]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0124, D_real=0.944]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00779, D_real=0.919]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0237, D_real=0.83]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0198, D_real=0.785]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0589, D_real=0.791]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0403, D_real=0.972]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0448, D_real=0.981]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0503, D_real=0.764]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.195, D_real=0.81]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.176, D_real=0.842]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0621, D_real=0.943]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0189, D_real=0.998]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.253, D_real=0.895]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.037, D_real=0.945]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0495, D_real=0.938]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0178, D_real=0.986]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00888, D_real=0.972]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00642, D_real=0.991]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0429, D_real=0.949]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0395, D_real=0.917]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0374, D_real=0.98]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0681, D_real=0.888]
# => Saving checkpoint
# => Saving checkpoint
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0623, D_real=0.9]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00854, D_real=0.996]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0294, D_real=0.698]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0448, D_real=0.972]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0271, D_real=0.992]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0183, D_real=0.97]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0614, D_real=0.946]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.173, D_real=0.792]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0573, D_real=0.986]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0411, D_real=0.978]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00964, D_real=0.976]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0265, D_real=0.966]
# 100%|█████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00627, D_real=0.994]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.108, D_real=0.899]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0105, D_real=0.869]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0274, D_real=0.988]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0494, D_real=0.893]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.241, D_real=0.254]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00443, D_real=0.943]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0337, D_real=0.966]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0163, D_real=0.94]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.123, D_real=0.845]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0504, D_real=0.793]
# 100%|█████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00141, D_real=0.991]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0428, D_real=0.982]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.017, D_real=0.939]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0137, D_real=0.996]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.265, D_real=0.665]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00793, D_real=0.982]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0286, D_real=0.96]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0468, D_real=0.863]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0466, D_real=0.817]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0286, D_real=0.886]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0837, D_real=0.908]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0226, D_real=0.882]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0337, D_real=0.991]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0579, D_real=0.642]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.186, D_real=0.72]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0345, D_real=0.975]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0483, D_real=0.968]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0156, D_real=0.94]
# 100%|█████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00718, D_real=0.988]
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.12, D_real=0.949]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.221, D_real=0.706]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.195, D_real=0.782]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0207, D_real=0.965]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0336, D_real=0.972]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0695, D_real=0.812]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00359, D_real=0.932]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.134, D_real=0.774]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00178, D_real=0.995]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0516, D_real=0.973]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0229, D_real=0.936]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0224, D_real=0.984]
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.175, D_real=0.75]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0459, D_real=0.827]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0204, D_real=0.979]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00979, D_real=0.944]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.391, D_real=0.516]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0279, D_real=0.979]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0162, D_real=0.874]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0392, D_real=0.967]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.015, D_real=0.973]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0767, D_real=0.815]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.048, D_real=0.941]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.179, D_real=0.755]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0523, D_real=0.983]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0746, D_real=0.886]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0238, D_real=0.972]
# 100%|█████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00476, D_real=0.973]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0133, D_real=0.989]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0629, D_real=0.951]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0328, D_real=0.987]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0208, D_real=0.911]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.156, D_real=0.666]
# => Saving checkpoint
# => Saving checkpoint
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.28, D_real=0.699]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.152, D_real=0.826]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.159, D_real=0.806]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.105, D_real=0.697]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.015, D_real=0.941]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0994, D_real=0.918]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0754, D_real=0.929]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0126, D_real=0.991]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.162, D_real=0.841]
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.13, D_real=0.702]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0808, D_real=0.908]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0389, D_real=0.87]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.067, D_real=0.848]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0104, D_real=0.638]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0107, D_real=0.981]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00565, D_real=0.974]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0813, D_real=0.806]
# 100%|█████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.1, D_real=0.919]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0684, D_real=0.894]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0551, D_real=0.947]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0161, D_real=0.962]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.281, D_real=0.398]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0408, D_real=0.877]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0628, D_real=0.793]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0567, D_real=0.983]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0109, D_real=0.991]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.133, D_real=0.846]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0353, D_real=0.895]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.124, D_real=0.783]
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.14, D_real=0.774]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0376, D_real=0.891]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0243, D_real=0.879]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0334, D_real=0.938]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0723, D_real=0.903]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0349, D_real=0.927]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0513, D_real=0.873]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0302, D_real=0.978]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.321, D_real=0.628]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0753, D_real=0.985]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0231, D_real=0.985]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.028, D_real=0.978]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.258, D_real=0.642]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.297, D_real=0.119]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0551, D_real=0.959]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.133, D_real=0.802]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0656, D_real=0.878]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.168, D_real=0.714]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0993, D_real=0.946]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0956, D_real=0.814]
# 100%|██████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.5, D_real=0.68]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0966, D_real=0.62]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.153, D_real=0.836]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.441, D_real=0.576]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0491, D_real=0.953]
# 100%|█████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00137, D_real=0.991]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.18it/s, D_fake=0.0207, D_real=0.924]
# 100%|███████████████| 69/69 [00:21<00:00,  3.19it/s, D_fake=0.116, D_real=0.823]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.198, D_real=0.772]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.027, D_real=0.988]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0888, D_real=0.927]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0132, D_real=0.982]
# 100%|████████████████| 69/69 [00:21<00:00,  3.19it/s, D_fake=0.126, D_real=0.84]
# 100%|███████████████| 69/69 [00:21<00:00,  3.19it/s, D_fake=0.124, D_real=0.931]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.143, D_real=0.789]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.036, D_real=0.982]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.05, D_real=0.95]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0585, D_real=0.865]
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.018, D_real=0.99]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00649, D_real=0.99]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0297, D_real=0.973]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.221, D_real=0.654]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0732, D_real=0.906]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0153, D_real=0.967]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0568, D_real=0.969]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.037, D_real=0.896]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0726, D_real=0.931]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0753, D_real=0.794]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0776, D_real=0.76]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.219, D_real=0.674]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0712, D_real=0.898]
# => Saving checkpoint
# => Saving checkpoint
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.017, D_real=0.97]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.367, D_real=0.568]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.141, D_real=0.908]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0736, D_real=0.882]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0253, D_real=0.994]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.19it/s, D_fake=0.0924, D_real=0.944]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.105, D_real=0.837]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0364, D_real=0.964]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0152, D_real=0.96]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0573, D_real=0.936]
# => Saving checkpoint
# => Saving checkpoint
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.157, D_real=0.86]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.508, D_real=0.497]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.189, D_real=0.885]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0205, D_real=0.982]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.107, D_real=0.859]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.327, D_real=0.627]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.228, D_real=0.577]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00874, D_real=0.987]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0254, D_real=0.997]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.111, D_real=0.784]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00141, D_real=0.995]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0403, D_real=0.921]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.383, D_real=0.581]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0836, D_real=0.84]
# 100%|█████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.13, D_real=0.83]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.00759, D_real=0.956]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.267, D_real=0.426]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.643, D_real=0.262]
# 100%|█████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.00742, D_real=0.994]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.127, D_real=0.867]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0181, D_real=0.993]
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.19, D_real=0.219]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0596, D_real=0.905]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.306, D_real=0.645]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0161, D_real=0.988]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0583, D_real=0.899]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.208, D_real=0.782]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.326, D_real=0.536]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.336, D_real=0.764]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0211, D_real=0.988]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0153, D_real=0.987]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0525, D_real=0.928]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.132, D_real=0.79]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.634, D_real=0.474]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0154, D_real=0.93]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.071, D_real=0.922]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.223, D_real=0.833]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.106, D_real=0.866]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0313, D_real=0.905]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0177, D_real=0.984]
# => Saving checkpoint
# => Saving checkpoint
# 100%|█████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.25, D_real=0.68]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0569, D_real=0.798]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0258, D_real=0.961]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0543, D_real=0.936]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0335, D_real=0.946]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0659, D_real=0.866]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.557, D_real=0.477]
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.169, D_real=0.59]
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.298, D_real=0.54]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.253, D_real=0.616]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0999, D_real=0.812]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.183, D_real=0.385]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.671, D_real=0.382]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0812, D_real=0.819]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.101, D_real=0.943]
# => Saving checkpoint
# => Saving checkpoint
# 100%|████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.166, D_real=0.78]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0267, D_real=0.979]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0361, D_real=0.962]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0697, D_real=0.93]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0684, D_real=0.937]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0492, D_real=0.864]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0963, D_real=0.751]
# 100%|█████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.1, D_real=0.674]
# 100%|███████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.235, D_real=0.796]
# 100%|█████████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.276, D_real=0.7]
# => Saving checkpoint
# => Saving checkpoint
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.122, D_real=0.75]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0454, D_real=0.965]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0341, D_real=0.931]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0961, D_real=0.821]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0269, D_real=0.983]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0906, D_real=0.637]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0567, D_real=0.917]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0884, D_real=0.93]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0573, D_real=0.913]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0761, D_real=0.888]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0946, D_real=0.867]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.058, D_real=0.978]
# 100%|██████████████| 69/69 [00:21<00:00,  3.21it/s, D_fake=0.0816, D_real=0.911]
# 100%|████████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.044, D_real=0.99]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0744, D_real=0.884]
# => Saving checkpoint
# => Saving checkpoint
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.216, D_real=0.808]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.214, D_real=0.724]
# 100%|████████████████| 69/69 [00:21<00:00,  3.19it/s, D_fake=0.147, D_real=0.64]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0955, D_real=0.929]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.146, D_real=0.862]
# => Saving checkpoint
# => Saving checkpoint
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0672, D_real=0.862]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0418, D_real=0.911]
# 100%|██████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.0296, D_real=0.976]
# 100%|███████████████| 69/69 [00:21<00:00,  3.20it/s, D_fake=0.607, D_real=0.366]
